# %% [markdown]
# # Applications
#
# [link](https://ut.philkr.net/deeplearning/transformers/applications/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
