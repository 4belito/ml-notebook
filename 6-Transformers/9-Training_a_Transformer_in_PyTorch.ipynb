# %% [markdown]
# # Training a Transformer in PyTorch
#
# [link](https://ut.philkr.net/deeplearning/transformers/training_a_transformer_in_pytorch/)

# %%
from model.transformer.transformerencoder import TransformerEncoderLayer

# %%
ord('b')
# Out:
# 98
