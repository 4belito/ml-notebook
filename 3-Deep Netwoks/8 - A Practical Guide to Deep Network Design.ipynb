# %% [markdown]
# # A Practical Guide to Deep Network Design
#
# [link](https://ut.philkr.net/deeplearning/deep_networks/a_practical_guide_to_deep_network_design/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
