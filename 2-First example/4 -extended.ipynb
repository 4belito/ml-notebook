# %%
# Imports
import torch

# %%
# Let's create a new tensor and use requires_grad=True

a = torch.rand(10, requires_grad=True)
a
# Out:
# tensor([0.7144, 0.7951, 0.9549, 0.1301, 0.7697, 0.0374, 0.5365, 0.1826, 0.4337,
#         0.2327], requires_grad=True)

# %%
# Let's build up a computation graph
# notice how this tensor had a special function called grad_fn

b = a * 2
b
# Out:
# tensor([1.4289, 1.5901, 1.9098, 0.2602, 1.5393, 0.0748, 1.0730, 0.3653, 0.8673,
#         0.4654], grad_fn=<MulBackward0>)

# %%
# Lets compute one more tensor
c = b.mean()
c
# Out:
# tensor(0.9574, grad_fn=<MeanBackward0>)

# %%
# Since this is a scalar we can call backward on it
c.backward()

# %%
# Now we can see the gradients of a
a.grad
# Out:
# tensor([0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000, 0.2000,
#         0.2000])

# %%
torch.cuda.memory_allocated()
# Out:
# 0

# %%
a = torch.rand(2**20, requires_grad=True, device="cuda")
torch.cuda.memory_allocated() / 1024.0**2
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a = torch.rand(2**20, requires_grad=True, device="cuda")
#       2 torch.cuda.memory_allocated() / 1024.0**2
#
# File /opt/anaconda3/envs/learn/lib/python3.11/site-packages/torch/cuda/__init__.py:403, in _lazy_init()
#     398     raise RuntimeError(
#     399         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     400         "multiprocessing, you must use the 'spawn' start method"
#     401     )
#     402 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 403     raise AssertionError("Torch not compiled with CUDA enabled")
#     404 if _cudart is None:
#     405     raise AssertionError(
#     406         "libcudart functions unavailable. It looks like you have a broken build?"
#     407     )
#
# AssertionError: Torch not compiled with CUDA enabled

# %%
b = torch.relu(a)
torch.cuda.memory_allocated() / 1024.0**2
# Out:
# 0.0

# %%
b = a
for _ in range(100):
    b = torch.relu(b)
torch.cuda.memory_allocated() / 1024.0**2
# Out:
# 0.0

# %%
b.sum().backward()
torch.cuda.memory_allocated() / 1024.0**2
# Out:
# 0.0

# %%
a.grad
# Out:
# tensor([1.2000, 1.2000, 1.2000, 1.2000, 1.2000, 1.2000, 1.2000, 1.2000, 1.2000,
#         1.2000])
