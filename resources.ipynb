# %%
import psutil

print("CPUs:", psutil.cpu_count())
print("RAM (GB):", round(psutil.virtual_memory().total / 1e9, 2))
print("Disk (GB):", round(psutil.disk_usage('/').total / 1e9, 2))
# Out:
# CPUs: 12
# RAM (GB): 19.33
# Disk (GB): 494.38
