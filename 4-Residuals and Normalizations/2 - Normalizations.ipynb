# %% [markdown]
# # Normalizations
#
# [link](https://ut.philkr.net/deeplearning/residuals_and_normalizations/normalizations/)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
